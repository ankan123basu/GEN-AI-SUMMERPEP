# %%
pip install langchain langchain-openai
# Out:
# ...
#
#   Attempting uninstall: websockets
#
#     Found existing installation: websockets 16.1.1
#
#     Uninstalling websockets-16.1.1:
#
#       Successfully uninstalled websockets-16.1.1
#
#    ---------------------------------------- 0/8 [websockets]
#    ---------------------------------------- 0/8 [websockets]
#    ---------------------------------------- 0/8 [websockets]
#    ---------------------------------------- 0/8 [websockets]
#    ---------------------------------------- 0/8 [websockets]
#    ---------------------------------------- 0/8 [websockets]
#    ---------------------------------------- 0/8 [websockets]
#    ---------------------------------------- 0/8 [websockets]
#    ---------------------------------------- 0/8 [websockets]
#    ---------------------------------------- 0/8 [websockets]
#    ---------------------------------------- 0/8 [websockets]
#    ---------------------------------------- 0/8 [websockets]
# ...

# %%
Langchain is a framework for developing applications powered by language models. It provides tools and abstractions to simplify the integration of language models into various applications, enabling developers to build conversational agents, question-answering systems, and other AI-driven solutions.

# %%
from getpass import getpass
import os
openai_api_key = getpass("Enter your OpenAI API key: ")
os.environ["OPENAI_API_KEY"] = openai_api_key

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
llm = ChatOpenAI(model = "gpt-4o-mini")

# %%
response = llm.invoke([HumanMessage(content="tell me about india")])
print(response.content)
# Out:
# India is a country in South Asia, known for its rich history, diverse cultures, and significant contributions to various fields, including philosophy, science, and the arts. Here are some key points about India:
#
# ### Geography
# - **Location:** Bordered by Pakistan to the west, China and Nepal to the north, Bhutan to the northeast, and Bangladesh and Myanmar to the east. The Indian Ocean lies to the south.
# - **Area:** It is the seventh-largest country in the world, covering approximately 3.29 million square kilometers.
#
# ### Population
# - India is the second-most populous country in the world, with over 1.4 billion people, representing a wide range of ethnicities, languages, and religions.
#
# ### Languages
# - India is a linguistically diverse country with 22 officially recognized languages, including Hindi, Bengali, Telugu, Marathi, Tamil, Urdu, and many more. English is also widely used, especially in government and business.
#
# ### Culture and Religion
# ...

# %%
messages = [
    SystemMessage(content="You are a helpful engineering tutor. keep answers to one sentence."),
    HumanMessage(content="What is retrieval augmented generation?"),
]
response = llm.invoke(messages)
print(response.content)
# Out:
# Retrieval-augmented generation (RAG) is a neural network architecture that combines generative models with retrieval systems to enhance the quality and accuracy of generated text by incorporating relevant information retrieved from external data sources.

# %%
pip install langchain langchain_google_genai
# Out:
# ...
#
#    ---------------------------------------- 0/2 [filetype]
#    ---------------------------------------- 0/2 [filetype]
#    -------------------- ------------------- 1/2 [langchain_google_genai]
#    -------------------- ------------------- 1/2 [langchain_google_genai]
#    -------------------- ------------------- 1/2 [langchain_google_genai]
#    ---------------------------------------- 2/2 [langchain_google_genai]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

# %%
from getpass import getpass
import os

gemini_api_key = getpass("Enter your Gemini API Key: ")

os.environ["GOOGLE_API_KEY"] = gemini_api_key

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-3.6-flash"
)

# %%
response = llm.invoke(
    [HumanMessage(content="Tell me about Antarctica.")]
)

print(response.content)
# Out:
# [{'type': 'text', 'text': '**Antarctica** is the earth’s southernmost continent, encapsulating the South Pole. It is a land of superlatives: it is the coldest, driest, windiest, highest, and most isolated continent on Earth. \n\nHere is a comprehensive breakdown of this unique frozen wilderness.\n\n---\n\n### 1. Geography and Extreme Climate\n* **Size:** It is the fifth-largest continent—roughly 1.4 times the size of the United States—covering about 14 million square kilometers (5.4 million square miles).\n* **The Ice Sheet:** Over 98% of Antarctica is covered by ice that averages **1.2 miles (1.9 kilometers) thick**. It holds roughly **90% of the world\'s ice** and **70% of its fresh water**.\n* **A Polar Desert:** Despite being made of water, Antarctica is technically a desert. The interior receives less than 2 inches (50 mm) of precipitation per year—less than the Sahara.\n* **Extreme Cold:** The lowest temperature ever recorded on Earth was at Russia’s Vostok Station in Antarctic
# ...

# %%
messages = [
    SystemMessage(
        content="You are a helpful engineering tutor. Keep answers in one sentence."
    ),
    HumanMessage(
        content="What is Retrieval-Augmented Generation?"
    )
]

response = llm.invoke(messages)

print(response.content)
# Out:
# [{'type': 'text', 'text': 'Retrieval-Augmented Generation (RAG) is an AI framework that enhances large language models by fetching relevant information from external knowledge sources to generate more accurate, context-aware, and up-to-date responses.', 'extras': {'signature': '...'}}]

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant that explains {topic} concepts simply."),
    ("human", "{question}")
])

print(prompt.input_variables)
# Out:
# ['question', 'topic']

# %%
formatted = prompt.invoke({
    "topic": "search",
    "question": "What is RAG?"
})
print(formatted.messages)
# Out:
# [SystemMessage(content='You are a helpful assistant that explains search concepts simply.', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is RAG?', additional_kwargs={}, response_metadata={})]

# %%
response = llm.invoke(formatted)
print(response.content)
# Out:
# [{'type': 'text', 'text': '**RAG** stands for **Retrieval-Augmented Generation**. \n\nIn simple terms, RAG is a technique that turns an AI chatbot from taking a **closed-book test** into taking an **open-book test**.\n\nHere is the easiest way to understand it:\n\n---\n\n### The "Open-Book" Analogy\n\n* **Standard AI (Closed-Book):** A regular AI model relies entirely on its memory—what it learned when it was trained. If you ask it about a specific company document or recent news, it might guess, get it wrong, or make things up (this is called "hallucinating").\n* **RAG AI (Open-Book):** When you ask a RAG system a question, it doesn\'t just guess. First, it **looks up the right textbook page** (retrieves the facts), reads it, and then **writes a clear answer** based on what it just read.\n\n---\n\n### How RAG Works in 3 Simple Steps\n\n1. **R – Retrieval (Search):** When you ask a question, the system searches through a specific collection of data (like your private documents, a com
# ...

# %%
# LCEL -> LangChain Expression Language
from langchain_core.output_parsers import StrOutputParser

# chain : prompt -> model -> parser
chain = prompt | llm | StrOutputParser()
result = chain.invoke({
    "topic": "search",
    "question": "What is cosine similarity?"
})
print(result)
# Out:
# **Cosine similarity** is a way to measure how similar two pieces of text (or two sets of data) are to each other, regardless of how long or short they are.
#
# Instead of looking at the *length* of the content, it looks at the **direction** the content is heading in topic-wise.
#
# ---
#
# ### The Easy Analogy: Clocks and Arrows
#
# Imagine two arrows starting at the same point:
#
# * **Pointing the same way:** If both arrows point in the exact same direction, the angle between them is 0 degrees. Their cosine similarity is **1** (They are identical in topic).
# * **Pointing at a right angle:** If the arrows are at a 90-degree angle, they share nothing in common. Their cosine similarity is **0** (Completely unrelated).
# * **Pointing in opposite directions:** If they point completely away from each other, their cosine similarity is **-1** (They are exact opposites).
#
# ---
#
# ### Why do we use it in Search and AI?
#
# ...
